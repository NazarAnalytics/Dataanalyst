# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Nazar\\Downloads\\Data Gyan'

# %%
import csv

# %% [markdown]
# # Reading Dataset From URL

# %%
df=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(5)
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %% [markdown]
# # Reading Dataset From Excel Files

# %%
df = pd.read_excel("Customers.xls","Sheet1")
df.head(5)
# Out:
#    CustomerID                        CustomerName         ContactName  \
# 0           1                 Alfreds Futterkiste        Maria Anders
# 1           2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2           3             Antonio Moreno Taquería      Antonio Moreno
# 3           4                     Around the Horn        Thomas Hardy
# 4           5                  Berglunds snabbköp  Christina Berglund
#
#                          Address         City PostalCode  Country
# 0                  Obere Str. 57       Berlin      12209  Germany
# 1  Avda. de la Constitución 2222  México D.F.       5021   Mexico
# 2                 Mataderos 2312  México D.F.       5023   Mexico
# 3                120 Hanover Sq.       London    WA1 1DP       UK
# 4                 Berguvsvägen 8        Luleå   S-958 22   Sweden

# %%
df = pd.read_excel("Zinavosalary.xls")
df.head(5)
# Out:
#   Employee ID   Employee Name   Department Designation  Basic Salary
# 0        ZO01           Nazar    Marketing         CEO         75000
# 1        ZO02   Karthik Keyan        Sales          MD         70000
# 2        ZO03        Sudhakar  Development          MD         68000
# 3        ZO04  Ashika Samreen      Analyst   Analytics         50000
# 4        ZO05          Mohana  Development   Developer         45000

# %%
df.tail()
# Out:
#    Employee ID Employee Name  Department Designation  Basic Salary
# 20        ZO21    Kaviarasan   Marketing   Analytics         10000
# 21        ZO22         Ashna          HR      Talent         10000
# 22        ZO23       Shakshi          HR      Talent         10000
# 23        ZO24        Hasini          HR      Talent         10000
# 24        ZO25        Zinavo  Management  Management        100000

# %% [markdown]
# # Reading Dataset From Text Files

# %%
df=pd.read_csv("intro.txt")
df
# Out:
#                                                                                         Hello Friends
# Thank You for Taking the Time to Visit my Profile   Mobile : 8951605480     Email : nazaranalytics...
# This is Nazar having 10+ years of experience in...  Located in BangaloreNow the file has more cont...

# %%
import csv

# %%
csv
# Out:
# <module 'csv' from 'C:\\Users\\Nazar\\Anaconda3\\lib\\csv.py'>

# %% [markdown]
# # Reading Dataset From CSV Files

# %%
df=pd.read_csv("50_Startups.csv")
df.head(5)
df.tail(5)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...
